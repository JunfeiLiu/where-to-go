# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

canteen = pd.read_csv("real_time_canteen.csv")
plt.plot(canteen['time'],canteen['canteen'])
plt.xticks(rotation=90)
plt.show()

library = pd.read_csv("real_time_library.csv")
plt.plot(library['time'],library['library'])
plt.xticks(rotation=90)
plt.show()

real_time_else = pd.read_csv("real_time_else.csv")
plt.plot(real_time_else['time'],real_time_else['else'])
plt.xticks(rotation=90)
plt.show()

    
plt.plot(canteen['time'],canteen['canteen']/70)
plt.plot(library['time'],library['library']/40)
plt.xticks(rotation=90)
plt.show()
#canteenlist=population["canteen"]

#print(canteenlist)
#np.array([[canteenlist[1]/canteenlist[0],(canteenlist[1]-canteenlist[0])/200],[(canteenlist[0]-canteenlist[1])/canteenlist[0],(200-canteenlist[1])/(200-canteenlist[0])]])
