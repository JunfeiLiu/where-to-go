# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

population=pd.read_csv("population.csv")
population['time']=pd.to_datetime(population['time'])
plt.plot(population['time'],population['canteen'])
plt.xticks(rotation=90)
plt.show()

population=pd.read_csv("population.csv")
population['time']=pd.to_datetime(population['time'])
plt.plot(population['time'],population['gym'])
plt.xticks(rotation=90)
plt.show()

population=pd.read_csv("population.csv")
population['time']=pd.to_datetime(population['time'])
plt.plot(population['time'],population['library'])
plt.xticks(rotation=90)
plt.show()

canteenlist=population["canteen"]

#print(canteenlist)
#np.array([[canteenlist[1]/canteenlist[0],(canteenlist[1]-canteenlist[0])/200],[(canteenlist[0]-canteenlist[1])/canteenlist[0],(200-canteenlist[1])/(200-canteenlist[0])]])

np.array([[0.9,0.03,0.0],[0.05,1.08],[0.05,-0.05,]])
# Out:
# 0      20
# 1      21
# 2      22
# 3      23
# 4      24
# 5      25
# 6      26
# 7      27
# 8      28
# 9      29
# 10     30
# 11     31
# 12     32
# 13     33
# 14     34
# 15     35
# 16     36
# 17     37
# 18     38
# 19     39
# 20     40
# 21     33
# 22     34
# 23     35
# 24     36
# 25     37
# 26     38
# 27     39
# 28     40
# 29     41
#        ..
# 335     0
# 336     0
# 337     0
# 338     0
# 339     0
# 340     0
# 341     0
# 342     0
# 343     0
# 344     0
# 345     0
# 346     0
# 347     0
# 348     0
# 349     0
# 350     0
# 351     0
# 352     0
# 353     0
# 354     0
# 355     0
# 356     0
# 357     0
# 358     0
# 359     0
# 360     0
# 361     0
# 362     0
# 363     0
# 364     0
# Name: canteen, Length: 365, dtype: int64
# array([[ 1.05      ,  0.005     ],
#        [-0.05      ,  0.99444444]])
